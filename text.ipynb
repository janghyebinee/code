# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 465 kB 56.3 MB/s
# ...

# %%
from konlpy.tag import Kkma, Komoran, Okt, Hannanum

# %%
okt = Okt()
kkma = Kkma()
komoran = Komoran()
hannanum = Hannanum()

# %%
text = '나랏말이 중국과 달라 한자와 서로 통하지 아니하므로, \
    우매한 백성들이 말하고 싶은 것이 있어도 마침내 제 뜻을 잘 표현하지 못하는 사람이 많다.\
    내 이를 딱하게 여기어 새로 스물여덟 자를 만들었으니, \
    사람들로 하여금 쉬 익히어 날마다 쓰는 데 편하게 할 뿐이다.'

# %% [markdown]
# # morphs: 형태소 단위로 나누어주는 함수

# %%
print("[Kkma morphs 함수]")
print(kkma.morphs(text))
# Out:
# [Kkma morphs 함수]
# ['나랏말', '이', '중국', '과', '닿', 'ㄹ라', '한자', '와', '서로', '통하', '지', '아니하', '므로', ',', '우매', '하', 'ㄴ', '백성', '들', '이', '말하', '고', '싶', '은', '것', '이', '있', '어도', '마침내', '저', '의', '뜻', '을', '잘', '표현', '하', '지', '못하', '는', '사람', '이', '많', '다', '.', '내', '이르', 'ㄹ', '딱하', '게', '여기', '어', '새로', '스물', '여덟', '자', '를', '만들', '었', '으니', ',', '사람', '들', '로', '하여금', '쉬', '익히', '어', '날', '마다', '쓰', '는', '데', '편하', '게', '하', 'ㄹ', '뿐', '이', '다', '.']

# %%
print("[Okt 함수]")
print(okt.morphs(text))
# Out:
# [Okt 함수]
# ['나랏말', '이', '중국', '과', '달라', '한자', '와', '서로', '통', '하지', '아니하므로', ',', '우매', '한', '백성', '들', '이', '말', '하고', '싶은', '것', '이', '있어도', '마침내', '제', '뜻', '을', '잘', '표현', '하지', '못', '하는', '사람', '이', '많다', '.', '내', '이를', '딱하게', '여기어', '새로', '스물', '여덟', '자를', '만들었으니', ',', '사람', '들', '로', '하여금', '쉬', '익히어', '날', '마다', '쓰는', '데', '편하게', '할', '뿐', '이다', '.']

# %%
# Okt에는 추가로 norm(문장 정규화), stem(각 단어에서 어간 추출) 옵션 존재
print("[Okt 함수: stem사용하여 어간 추출]")
print(okt.morphs(text, stem= True))
# Out:
# [Okt 함수: stem사용하여 어간 추출]
# ['나랏말', '이', '중국', '과', '달라', '한자', '와', '서로', '통', '하다', '아니다', ',', '우매', '한', '백성', '들', '이', '말', '하고', '싶다', '것', '이', '있다', '마침내', '제', '뜻', '을', '자다', '표현', '하다', '못', '하다', '사람', '이', '많다', '.', '내', '이르다', '딱하다', '여기다', '새롭다', '스물', '여덟', '자르다', '만들다', ',', '사람', '들', '로', '하여금', '쉬', '익히다', '날', '마다', '쓰다', '데', '편하다', '하다', '뿐', '이다', '.']

# %%
print("[Komoran 함수]")
print(komoran.morphs(text))
# Out:
# [Komoran 함수]
# ['나랏말이', '중국', '과', '다르', '아', '한자', '와', '서로', '통하', '지', '아니하', '므로', ',', '우매', '하', 'ㄴ', '백성', '들', '이', '말', '하', '고', '싶', '은', '것', '이', '있', '어도', '마침내', '제', '뜻', '을', '잘', '표현', '하', '지', '못하', '는', '사람', '이', '많', '다', '.', '내', '이', '를', '딱하', '게', '여기', '어', '새로', '스물', '여덟', '자', '를', '만들', '었', '으니', ',', '사람', '들', '로', '하여금', '쉬', '익히', '어', '날', '마다', '쓰', '는', '데', '편하', '게', '하', 'ㄹ', '뿐', '이', '다', '.']

# %%
print("[Hannanum 함수]")
print(hannanum.morphs(text))
# Out:
# [Hannanum 함수]
# ['나랏말', '이', '중국', '과', '다르', '아', '하', 'ㄴ', '자', '와', '서로', '통하', '지', '아니하', '므로', ',', '우매', '하', 'ㄴ', '백성들', '이', '말', '하고', '싶', '은', '것', '이', '있', '어도', '마침내', '저', '의', '뜻', '을', '잘', '표현', '하', '지', '못하', '는', '사람', '이', '많', '다', '.', '내', '이', '를', '딱하', '게', '여기', '이', '어', '새로', '스물여덟', '자', '를', '만들', '었으니', ',', '사람들', '로', '하여금', '쉬', '익히', '어', '날마다', '쓰', '는', '데', '편하', '게', '하', 'ㄹ', '뿐', '이', '다', '.']

# %% [markdown]
# # nouns: 품사 중 명사 추출 함수

# %%
print("[Kkma nouns 함수]")
print(kkma.nouns(text))
print("[OKt nouns 함수]")
print(okt.nouns(text))
print("[Komoran nouns 함수]")
print(komoran.nouns(text))
print("[Hannanum nouns 함수]")
print(hannanum.nouns(text))
# Out:
# [Kkma nouns 함수]
# ['나랏말', '중국', '한자', '우매', '백성', '저', '뜻', '표현', '사람', '내', '스물', '스물여덟', '여덟', '자', '로', '날', '데', '뿐']
# [OKt nouns 함수]
# ['나랏말', '중국', '달라', '한자', '서로', '통', '우매', '백성', '말', '것', '마침내', '제', '뜻', '표현', '사람', '내', '스물', '여덟', '사람', '쉬', '날', '데', '뿐']
# [Komoran nouns 함수]
# ['중국', '한자', '우매', '백성', '말', '것', '뜻', '표현', '사람', '자', '사람', '날', '데', '뿐']
# [Hannanum nouns 함수]
# ['나랏말', '중국', '자', '우매', '백성들', '말', '것', '저', '뜻', '표현', '사람', '내', '이', '여기', '스물여덟', '자', '사람들', '데', '뿐']

# %% [markdown]
# # phrases: 어절 추출 함수
# - Okt 라이브러리에만 있음

# %%
print("[Okt phrases 함수]")
print(okt.phrases(text))
# Out:
# [Okt phrases 함수]
# ['나랏말', '중국', '중국과 달라', '중국과 달라 한자', '중국과 달라 한자와 서로', '중국과 달라 한자와 서로 통', '우매', '백성들', '마침내', '마침내 제', '마침내 제 뜻', '표현', '못하는 사람', '스물여덟', '사람들', '달라', '한자', '서로', '사람', '스물', '여덟']

# %% [markdown]
# # pos: 문자의 각 품사를 보여줌
# - 품사 이름은 각 분석기별로 차이가 있음
# - https://docs.google.com/spreadsheets/d/1OGAjUvalBuX-oZvZ_-9tEfYD2gQe7hTGsgUpiiBSXI8/edit#gid=0

# %%
print("[Kkma pos 함수]")
print(kkma.pos(text)) #join=True는 형태소와 품사를 붙여서 리스트화
print("[Okt pos 함수]")
print(okt.pos(text))
print("[Komoran pos 함수]")
print(komoran.pos(text))
print("[Hannanum pos 함수]")
print(hannanum.pos(text))
# Out:
# [Kkma pos 함수]
# ...

# %% [markdown]
# # 텍스트 빈도 분석

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# 텍스트 불러오기/
f = open("/content/소나기.txt", 'rt', encoding = 'utf-8')
lines = f.readlines()
line = []
for i in range(len(lines)):
  line.append(lines[i])
f.close()

print(line)
# Out:
# ['소년은 개울가에서 소녀를 보자 곧 윤 초시네 증손녀 딸이라는 걸 알 수\n', '있었다. 소녀는 개울에다 손을 잠그고 물장난을 하고 있는 것이다. 서울서는 이런\n', '개울물을 보지 못하기나 한 듯이.\n', '벌써 며칠째 소녀는, 학교에서 돌아오는 길에 물장난이었다. 그런데, 어제까지 개울\n', '기슭에서 하더니, 오늘은 징검다리 한가운데 앉아서 하고 있다.\n', '소년은 개울둑에 앉아 버렸다. 소녀가 비키기를 기다리자는 것이다.\n', '요행 지나가는 사람이 있어, 소녀가 길을 비켜 주었다.\n', '다음 날은 좀 늦게 개울가로 나왔다.\n', '이 날은 소녀가 징검다리 한가운데 앉아 세수를 하고 있었다. 분홍 스웨터 소매를\n', '걷어올린 목덜미가 마냥 희었다.\n', '한참 세수를 하고 나더니, 이번에는 물 속을 빤히 들여다 본다. 얼굴이라도 비추어\n', '보는 것이리라. 갑자기 물을 움켜 낸다. 고기 새끼라도 지나가는 듯.\n', '소녀는 소년이 개울둑에 앉아 있는 걸 아는지 모르는지 그냥 날쌔게 물만 움켜\n', '낸다. 그러나, 번번이 허탕이다. 그대로 재미있는 양, 자꾸 물만 움킨다. 어제처럼\n', '개울을 건너는 사람이 있어야 길을 비킬 모양이다.\n', '그러다가 소녀가 물 속에서 무엇을 하나 집어 낸다. 하얀 조약돌이었다. 그리고는\n', '벌떡 일어나 팔짝팔짝 징검다리를 뛰어 건너간다.\n', '다 건너가더니만 홱 이리로 돌아서며,\n', '"이 바보."\n', '조약돌이 날아왔다.\n', '소년은 저도 모르게 벌떡 일어섰다.\n', '단발 머리를 나풀거리며 소녀가 막 달린다. 갈밭 사잇길로 들어섰다. 뒤에는 청량한\n', '가을 햇살 아래 빛나는 갈꽃뿐.\n', '이제 저쯤 갈밭머리로 소녀가 나타나리라. 꽤 오랜 시간이 지났다고 생각됐다.\n', '그런데도 소녀는 나타나지 않는다. 발돋움을 했다. 그러고도 상당한 시간이\n', '지났다고 생각됐다.\n', '저 쪽 갈밭머리에 갈꽃이 한 옴큼 움직였다. 소녀가 갈꽃을 안고
# ...

# %%
# 텍스트 특수문자 지워주기
import re
compile = re.compile("[^ ㄱ-ㅣ가-힣]+")
for i in range(len(line)):

  a = compile.sub("", line[i])
  line[i]=a

print(line)
# Out:
# ['소년은 개울가에서 소녀를 보자 곧 윤 초시네 증손녀 딸이라는 걸 알 수', '있었다 소녀는 개울에다 손을 잠그고 물장난을 하고 있는 것이다 서울서는 이런', '개울물을 보지 못하기나 한 듯이', '벌써 며칠째 소녀는 학교에서 돌아오는 길에 물장난이었다 그런데 어제까지 개울', '기슭에서 하더니 오늘은 징검다리 한가운데 앉아서 하고 있다', '소년은 개울둑에 앉아 버렸다 소녀가 비키기를 기다리자는 것이다', '요행 지나가는 사람이 있어 소녀가 길을 비켜 주었다', '다음 날은 좀 늦게 개울가로 나왔다', '이 날은 소녀가 징검다리 한가운데 앉아 세수를 하고 있었다 분홍 스웨터 소매를', '걷어올린 목덜미가 마냥 희었다', '한참 세수를 하고 나더니 이번에는 물 속을 빤히 들여다 본다 얼굴이라도 비추어', '보는 것이리라 갑자기 물을 움켜 낸다 고기 새끼라도 지나가는 듯', '소녀는 소년이 개울둑에 앉아 있는 걸 아는지 모르는지 그냥 날쌔게 물만 움켜', '낸다 그러나 번번이 허탕이다 그대로 재미있는 양 자꾸 물만 움킨다 어제처럼', '개울을 건너는 사람이 있어야 길을 비킬 모양이다', '그러다가 소녀가 물 속에서 무엇을 하나 집어 낸다 하얀 조약돌이었다 그리고는', '벌떡 일어나 팔짝팔짝 징검다리를 뛰어 건너간다', '다 건너가더니만 홱 이리로 돌아서며', '이 바보', '조약돌이 날아왔다', '소년은 저도 모르게 벌떡 일어섰다', '단발 머리를 나풀거리며 소녀가 막 달린다 갈밭 사잇길로 들어섰다 뒤에는 청량한', '가을 햇살 아래 빛나는 갈꽃뿐', '이제 저쯤 갈밭머리로 소녀가 나타나리라 꽤 오랜 시간이 지났다고 생각됐다', '그런데도 소녀는 나타나지 않는다 발돋움을 했다 그러고도 상당한 시간이', '지났다고 생각됐다', '저 쪽 갈밭머리에 갈꽃이 한 옴큼 움직였다 소녀가 갈꽃을 안고 있었다 그리고', '이제는 천천한 걸음이었다 유난히 맑은 가을 햇살이 소녀의 갈꽃머리에서', '반짝거렸다 소녀 아닌 갈꽃이 들길을 걸어가는 것만 같았다', '소년은 이 갈
# ...

# %%
# 불용어 제거(사용하지 않는 단어, 분석 시 필요 없는 단어)
# ex) 이었다, 것이다 와 같은

stop_word = ["허 참 세상일도", "내면서", "것이다"] # 사용하지 않을 단어 또는 문장 추가
line = [i for i in line if i not in stop_word]

# %%
# 문장분석
# 품사 분석
# Okt 함수를 사용하여 명사만 추출

result= []
result = [okt.nouns(i) for i in line] # 명사만 추출
final_result = [r for i in result for r in i]
print(final_result)
# Out:
# ['소년', '소녀', '곧', '윤', '초시', '증손녀', '딸', '걸', '알', '수', '소녀', '개울', '손', '물장난', '것', '서울', '개울물', '보지', '듯이', '벌써', '며칠', '소녀', '학교', '길', '물장난', '어제', '개울', '기슭', '오늘', '징', '한가운데', '소년', '개울', '둑', '소녀', '비키', '것', '요행', '사람', '소녀', '길', '다음', '날', '좀', '개울', '가로', '이', '날', '소녀', '징', '한가운데', '세수', '분홍', '스웨터', '소매', '목덜미', '마냥', '한참', '세수', '이번', '물', '속', '얼굴', '것', '리라', '갑자기', '물', '고기', '새끼', '듯', '소녀', '소년', '개울', '둑', '걸', '그냥', '날쌔', '물', '번번이', '허탕', '그대로', '양', '자꾸', '물', '어제', '개울', '사람', '길', '모양', '소녀', '물', '속', '무엇', '하나', '조약돌', '벌떡', '징검', '다리', '홱', '리', '이', '바보', '조약돌', '소년', '저', '벌떡', '단발', '머리', '소녀', '막', '달린다', '밭', '사', '뒤', '가을', '햇살', '아래', '꽃', '이제', '쯤', '밭머리', '소녀', '꽤', '시간', '생각', '소녀', '발돋움', '시간', '생각', '저', '쪽', '밭머리', '꽃', '옴', '소녀', '꽃', '안고', '이제', '천천', '걸음', '맑은', '가을', '햇살', '소녀', '꽃', '머리', '소녀', '꽃', '길', '것', '소년', '이', '꽃', '아주', '그대로', '문득', '소녀', '조약돌', '물기', '소년', '조약돌', '주머니', '다음', '날', '좀더', '개울', '가로', '소녀', '그림자', '다행', '일', '소
# ...

# %%
# 단어 수 세기
# 텍스트에서 많이 나온 단어 섹
import pandas as pd
korean = pd.Series(final_result).value_counts().head(10)
print("한국어 상위 10개 단어")
print(korean)
# Out:
# 한국어 상위 10개 단어
# 소녀    72
# 소년    49
# 꽃     24
# 것     20
# 속     15
# 이     15
# 날     14
# 비     13
# 그     13
# 생각    13
# dtype: int64

# %% [markdown]
# # 한글 파일 텍스트 추출
# - 한글파일이 .hwpx로 되어 있으면 안열리고 .hwp로 되어 있어야 열림

# %%
pip install olefile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 112 kB 4.9 MB/s
# ...
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35430 sha256=bb3706e2d0d83f857c139c073ba9888641894491f968da872154d579b7f6e51a
#   Stored in directory: /root/.cache/pip/wheels/0b/d8/16/1e2d32ad7455728b8af9efdb9d2a0c3d03cd8f2e4be0191b8c
# Successfully built olefile
# ...

# %%
import olefile
import zlib
import struct

# %%
def get_hwp_text(filename):
    f = olefile.OleFileIO(filename)
    dirs = f.listdir()

# %%
def get_hwp_text(filename):
    f = olefile.OleFileIO(filename)
    dirs = f.listdir()

    # HWP 파일 검증
    if ["FileHeader"] not in dirs or \
       ["\x05HwpSummaryInformation"] not in dirs:
        raise Exception("Not Valid HWP.")

    # 문서 포맷 압축 여부 확인
    header = f.openstream("FileHeader")
    header_data = header.read()
    is_compressed = (header_data[36] & 1) == 1

    # Body Sections 불러오기
    nums = []
    for d in dirs:
        if d[0] == "BodyText":
            nums.append(int(d[1][len("Section"):]))
    sections = ["BodyText/Section"+str(x) for x in sorted(nums)]

    # 전체 text 추출
    text = ""
    for section in sections:
        bodytext = f.openstream(section)
        data = bodytext.read()
        if is_compressed:
            unpacked_data = zlib.decompress(data, -15)
        else:
            unpacked_data = data
    
        # 각 Section 내 text 추출    
        section_text = ""
        i = 0
        size = len(unpacked_data)
        while i < size:
            header = struct.unpack_from("<I", unpacked_data, i)[0]
            rec_type = header & 0x3ff
            rec_len = (header >> 20) & 0xfff

            if rec_type in [67]:
                rec_data = unpacked_data[i+4:i+4+rec_len]
                section_text += rec_data.decode('utf-16')
                section_text += "\n"

            i += 4 + rec_len

        text += section_text
        text += "\n"

    return text


file_name = '/content/공고문.hwp'
print(get_hwp_text(file_name))
# Out:
# 捤獥汤捯김해시 공고 제2022-   호
# 김해동상시장 청년몰 청년상인 모집 공고
# 김해동상시장 내에 위치한 동상시장 청년몰 빈 점포에 대하여 창업을 희망 하는 청년상인을 다음과 같이 모집 공고하오니 많은 참여 바랍니다.
# 2022.   12.   15.
# 김  해  시  장
# 1. 청년몰 개요
#  가. 위    치 : 김해시 구지로 180번길 25(동상동)
#  나. 건물규모 : 2~3층(1080.84㎡), 총 14개 점포(2층 7개, 3층 7개)
#  다. 입점현황
#    2층 : 201호(도시락), 202호(오리탕), 204호(창고), 205호(전시공간)
#            206호(국밥류), 207호(샐러드류), 209호(전시공간), 210호(분식)
#    3층 : 302호(커피·디저트류), 304·305호(다문화카페), 306호(캔들·방향제),                307호(네일아트), 308호(타로·심리상담), 309호(그림공방)
# 氠瑢 라. 현황사진
# 청년몰 외부 및 주변(분성광장)
# 2. 모집개요
#  가. 氠瑢모집점포 : 3층 2개소
# 호수
# 면 적(㎡)
# 연간사용료(원)
# 계
# 전용면적
# 공유면적
# 301호
# 64.67
# 32.40
# 32.27
# 1,422,740원(월118,560)
# 303호
# 73.21
# 40.94
# 32.27
# 1,610,620원(월134,210)
#
#     ※ 면적(㎡)당 사용료 22,000원, 부가세(10%) 미포함
#  나. 모집분야
#    - 식품위생법 제21조(영업의종류)에 의한 식품접객업 중 휴게음식점 또는 제과점 영업(일반음식점 불가)
#    - 신청자의 창업 아이템에 따라, 점포 내 기존 시설물의 보존 및 활용   범위내에서 도·소매업 가능(부서와 사전 협의)
#  다. 신청자격
#    공고일 기준 관내 주소지를 둔 만19세 이상 만39세 이하 청년
# ...

# %%
f = get_hwp_text(file_name)
# 문자열 리스트로 만들어주기
f_ = [f]

# %%
f_
# Out:
# ['\x02捤獥\x00\x00\x00\x00\x02\x02汤捯\x00\x00\x00\x00\x02김해시 공고 제2022-   호 \r\n김해동상시장 청년몰 청년상인 모집 공고\r\n김해동상시장 내에 위치한 동상시장 청년몰 빈 점포에 대하여 창업을 희망 하는 청년상인을 다음과 같이 모집 공고하오니 많은 참여 바랍니다.\r\n2022.   12.   15. \r\n김  해  시  장\r\n1. 청년몰 개요\r\n 가. 위    치 : 김해시 구지로 180번길 25(동상동)\r\n 나. 건물규모 : 2~3층(1080.84㎡), 총 14개 점포(2층 7개, 3층 7개)\r\n 다. 입점현황\r\n  \uf06d 2층 : 201호(도시락), 202호(오리탕), 204호(창고), 205호(전시공간) \r\n           206호(국밥류), 207호(샐러드류), 209호(전시공간), 210호(분식) \r\n  \uf06d 3층 : 302호(커피·디저트류), 304·305호(다문화카페), 306호(캔들·방향제),                307호(네일아트), 308호(타로·심리상담), 309호(그림공방)\r\n\x0b氠瑢\x00\x00\x00\x00\x0b 라. 현황사진\r\n청년몰 외부 및 주변(분성광장)\r\n2. 모집개요\r\n 가. \x0b氠瑢\x00\x00\x00\x00\x0b모집점포 : 3층 2개소\r\n호수\r\n면 적(㎡)\r\n연간사용료(원)\r\n계\r\n전용면적\r\n공유면적\r\n301호\r\n64.67\r\n32.40\r\n32.27\r\n1,422,740원(월118,560)\r\n303호\r\n73.21\r\n40.94\r\n32.27\r\n1,610,620원(월134,210)\r\n    \r\n    ※ 면적(㎡)당 사용료 22,000원, 부가세(10%) 미포함\r\n 나. 모집분야 \r\n   - 식품위생법 제21조(영업의종류)에 의한 식품접객업 중 휴게음식점 또는 제과점 영업(일반음식점 불가)\r\n   - 신청자의 창업 아이템에 
# ...

# %%
# 특수문자 제거 - 문자만 남기기
import re

compile = re.compile("[^ ㄱ-ㅣ가-힣]+")
for i in range(len(f_)):

  a=compile.sub("",f_[i])
  f_[i]=a 
  
print(f_)
# Out:
# ['김해시 공고 제   호 김해동상시장 청년몰 청년상인 모집 공고김해동상시장 내에 위치한 동상시장 청년몰 빈 점포에 대하여 창업을 희망 하는 청년상인을 다음과 같이 모집 공고하오니 많은 참여 바랍니다       김  해  시  장 청년몰 개요 가 위    치  김해시 구지로 번길 동상동 나 건물규모  층 총 개 점포층 개 층 개 다 입점현황   층  호도시락 호오리탕 호창고 호전시공간            호국밥류 호샐러드류 호전시공간 호분식    층  호커피디저트류 호다문화카페 호캔들방향제                호네일아트 호타로심리상담 호그림공방 라 현황사진청년몰 외부 및 주변분성광장 모집개요 가 모집점포  층 개소호수면 적연간사용료원계전용면적공유면적호원월호원월         면적당 사용료 원 부가세 미포함 나 모집분야     식품위생법 제조영업의종류에 의한 식품접객업 중 휴게음식점 또는 제과점 영업일반음식점 불가    신청자의 창업 아이템에 따라 점포 내 기존 시설물의 보존 및 활용   범위내에서 도소매업 가능부서와 사전 협의  다 신청자격    공고일 기준 관내 주소지를 둔 만세 이상 만세 이하 청년   공고일 기준 사업자등록을 하지 않은 자단 사업자등록 이력이 있어도       폐업신고 등으로 신청일 현재 사업자가 아니면 신청가능    신청 제외 대상   피성년후견인 또는 피한정후견인   파산선고를 받고 복권되지 아니한 자   금고 이상의 실형 후 집행종료 또는 집행면제 후 년이 지나지 아니한 자   금고 이상의 실형 후 집행유예 기간이 끝난 날부터 년이 지나지 아니한 자   금고 이상의 형의 선고유예를 받은 경우에는 그 선고 유예기간 중에 있는 자   공무원이 업무상 횡령 및 배임 업무위력 등에 의한 간음 및 추행으로 만원 이상의     벌금형을 선고받고 퇴직한 날로부터 년이 지나지 아니한 자   공무원이 파면처분을 받고 퇴직한 날로부터 년이 지나지 아니한 자   공무원이 해임처분을 받고 퇴직한 날로부터 년이 지나지 아니한 자   국세 등 세금
# ...

# %% [markdown]
# ## 불용어 사전

# %%
stop_word = open('/content/불용어.txt','rt',encoding='utf-8')

# %%
stop_words = stop_word.readlines()
stop_word_ = []
for i in range(len(stop_words)):
  stop_word_.append(stop_words[i])
stop_word.close()

# %%
print(stop_word_)
# Out:
# ['아\n', '휴\n', '아이구\n', '아이쿠\n', '아이고\n', '어\n', '나\n', '우리\n', '저희\n', '따라\n', '의해\n', '을\n', '를\n', '에\n', '의\n', '가\n', '으로\n', '로\n', '에게\n', '뿐이다\n', '의거하여\n', '근거하여\n', '입각하여\n', '기준으로\n', '예하면\n', '예를 들면\n', '예를 들자면\n', '저\n', '소인\n', '소생\n', '저희\n', '지말고\n', '하지마\n', '하지마라\n', '다른\n', '물론\n', '또한\n', '그리고\n', '비길수 없다\n', '해서는 안된다\n', '뿐만 아니라\n', '만이 아니다\n', '만은 아니다\n', '막론하고\n', '관계없이\n', '그치지 않다\n', '그러나\n', '그런데\n', '하지만\n', '든간에\n', '논하지 않다\n', '따지지 않다\n', '설사\n', '비록\n', '더라도\n', '아니면\n', '만 못하다\n', '하는 편이 낫다\n', '불문하고\n', '향하여\n', '향해서\n', '향하다\n', '쪽으로\n', '틈타\n', '이용하여\n', '타다\n', '오르다\n', '제외하고\n', '이 외에\n', '이 밖에\n', '하여야\n', '비로소\n', '한다면 몰라도\n', '외에도\n', '이곳\n', '여기\n', '부터\n', '기점으로\n', '따라서\n', '할 생각이다\n', '하려고하다\n', '이리하여\n', '그리하여\n', '그렇게 함으로써\n', '하지만\n', '일때\n', '할때\n', '앞에서\n', '중에서\n', '보는데서\n', '으로써\n', '로써\n', '까지\n', '해야한다\n', '일것이다\n', '반드시\n', '할줄알다\n', '할수있다\n', '할수있어\n', '임에 틀림없다\n', '한다면\n', '등\n', '등등\n', '제\n', '겨우\n', '단지\n', '다만\n', '할뿐\n', '딩동
# ...

# %%
###특수문자 제거하기###
##한국어##
import re
compile = re.compile("[^ ㄱ-ㅣ가-힣]+")
for i in range(len(stop_word_)):

    a = compile.sub("",stop_word_[i])
    stop_word_[i] = a
print(stop_word_)
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라', '의해', '을', '를', '에', '의', '가', '으로', '로', '에게', '뿐이다', '의거하여', '근거하여', '입각하여', '기준으로', '예하면', '예를 들면', '예를 들자면', '저', '소인', '소생', '저희', '지말고', '하지마', '하지마라', '다른', '물론', '또한', '그리고', '비길수 없다', '해서는 안된다', '뿐만 아니라', '만이 아니다', '만은 아니다', '막론하고', '관계없이', '그치지 않다', '그러나', '그런데', '하지만', '든간에', '논하지 않다', '따지지 않다', '설사', '비록', '더라도', '아니면', '만 못하다', '하는 편이 낫다', '불문하고', '향하여', '향해서', '향하다', '쪽으로', '틈타', '이용하여', '타다', '오르다', '제외하고', '이 외에', '이 밖에', '하여야', '비로소', '한다면 몰라도', '외에도', '이곳', '여기', '부터', '기점으로', '따라서', '할 생각이다', '하려고하다', '이리하여', '그리하여', '그렇게 함으로써', '하지만', '일때', '할때', '앞에서', '중에서', '보는데서', '으로써', '로써', '까지', '해야한다', '일것이다', '반드시', '할줄알다', '할수있다', '할수있어', '임에 틀림없다', '한다면', '등', '등등', '제', '겨우', '단지', '다만', '할뿐', '딩동', '댕그', '대해서', '대하여', '대하면', '훨씬', '얼마나', '얼마만큼', '얼마큼', '남짓', '여', '얼마간', '약간', '다소', '좀', '조금', '다수', '몇', '얼마', '지만', '하물며', '또한', '그러나', '그렇지만', '하지만', '이외에도', '대해 말하자면', '뿐이다', '다음에', '반대로', '반대로 말하자면', '이와 반대로
# ...

# %% [markdown]
# ## 개수세기

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words_ = ["것, 및, 등, 에, 아니면"]

f_ = [i for i in f_ if i not in stop_words_]

# %%
print(f_)
# Out:
# ['김해시 공고 제   호 김해동상시장 청년몰 청년상인 모집 공고김해동상시장 내에 위치한 동상시장 청년몰 빈 점포에 대하여 창업을 희망 하는 청년상인을 다음과 같이 모집 공고하오니 많은 참여 바랍니다       김  해  시  장 청년몰 개요 가 위    치  김해시 구지로 번길 동상동 나 건물규모  층 총 개 점포층 개 층 개 다 입점현황   층  호도시락 호오리탕 호창고 호전시공간            호국밥류 호샐러드류 호전시공간 호분식    층  호커피디저트류 호다문화카페 호캔들방향제                호네일아트 호타로심리상담 호그림공방 라 현황사진청년몰 외부 및 주변분성광장 모집개요 가 모집점포  층 개소호수면 적연간사용료원계전용면적공유면적호원월호원월         면적당 사용료 원 부가세 미포함 나 모집분야     식품위생법 제조영업의종류에 의한 식품접객업 중 휴게음식점 또는 제과점 영업일반음식점 불가    신청자의 창업 아이템에 따라 점포 내 기존 시설물의 보존 및 활용   범위내에서 도소매업 가능부서와 사전 협의  다 신청자격    공고일 기준 관내 주소지를 둔 만세 이상 만세 이하 청년   공고일 기준 사업자등록을 하지 않은 자단 사업자등록 이력이 있어도       폐업신고 등으로 신청일 현재 사업자가 아니면 신청가능    신청 제외 대상   피성년후견인 또는 피한정후견인   파산선고를 받고 복권되지 아니한 자   금고 이상의 실형 후 집행종료 또는 집행면제 후 년이 지나지 아니한 자   금고 이상의 실형 후 집행유예 기간이 끝난 날부터 년이 지나지 아니한 자   금고 이상의 형의 선고유예를 받은 경우에는 그 선고 유예기간 중에 있는 자   공무원이 업무상 횡령 및 배임 업무위력 등에 의한 간음 및 추행으로 만원 이상의     벌금형을 선고받고 퇴직한 날로부터 년이 지나지 아니한 자   공무원이 파면처분을 받고 퇴직한 날로부터 년이 지나지 아니한 자   공무원이 해임처분을 받고 퇴직한 날로부터 년이 지나지 아니한 자   국세 등 세금
# ...

# %%
# 명사추출
result=[]
result = [okt.nouns(i) for i in f_]
final_result = [r for i in result for r in i]
print(final_result)
# Out:
# ['김해시', '공고', '제', '호', '김해', '동상', '시장', '청년', '청년', '상인', '모집', '공고', '김해', '동상', '시장', '내', '위치', '동상', '시장', '청년', '빈', '점포', '대하', '창업', '희망', '청년', '상인', '다음', '모집', '공고', '오니', '참여', '김', '해', '시', '장', '청년', '개요', '위', '치', '김해시', '구지', '번길', '동상동', '나', '건물', '규모', '층', '총', '개', '점포', '층', '개', '층', '개', '입점', '현황', '층', '호', '도시락', '호오리', '탕', '호', '창고', '호전', '시공간', '호', '국밥', '류', '호', '샐러드', '류', '호전', '시공간', '호분', '층', '호', '커피', '디저트', '류', '호', '다문화', '카페', '호', '캔들', '방향', '제', '호', '네일아트', '호타로', '심리상담', '호', '그림', '방', '현황', '사진', '청년', '외부', '및', '주변', '광장', '모집', '개요', '모집', '점포', '층', '호수', '적', '연간', '사용', '료', '계전', '용면', '공유', '면적', '호원', '월', '호원', '월', '면적', '사용', '료', '원', '부가세', '포함', '나', '모집', '분야', '식품위생법', '영업', '종류', '식품', '접객', '업', '중', '휴게', '음식점', '제과점', '영업일', '음식점', '불가', '신청', '자의', '창업', '아이템', '점포', '내', '기존', '시설', '물의', '보존', '및', '활용', '범위', '내', '도', '소매업', '가능', '부서', '사전', '협의', '신청', '자격', '공고', '일', '기준', '관내', '주소지', '만세', '이상', '만
# ...

# %%
 pd.Series(final_result).value_counts()
# Out:
# 및       46
# 청년      33
# 등       30
# 사업      27
# 개인정보    23
#         ..
# 재산관리     1
# 전반       1
# 재산       1
# 비        1
# 조회       1
# Length: 518, dtype: int64

# %%
# 단어 수 세기
korean = pd.Series(final_result).value_counts().head(20)
print(korean)
# Out:
# 및       46
# 청년      33
# 등       30
# 사업      27
# 개인정보    23
# 동의      20
# 이용      19
# 시장      18
# 것       16
# 수집      15
# 호       14
# 계획      14
# 상인      13
# 서류      13
# 관련      13
# 제공      12
# 창업      12
# 사항      12
# 상품      11
# 입점      11
# dtype: int64

# %%
f__=[f]

# %%
f__

# %%
# 특수문자 제거 - 문자, 숫자 남기기
import re

compile = re.compile("[^\uAC00-\uD7A30\0-9a-zA-Z\s]")
for i in range(len(f__)):

  a=compile.sub("",f__[i])
  f__[i]=a 
  
print(f__)
# Out:
# ['김해시 공고 제2022   호 \r\n김해동상시장 청년몰 청년상인 모집 공고\r\n김해동상시장 내에 위치한 동상시장 청년몰 빈 점포에 대하여 창업을 희망 하는 청년상인을 다음과 같이 모집 공고하오니 많은 참여 바랍니다\r\n2022   12   15 \r\n김  해  시  장\r\n1 청년몰 개요\r\n 가 위    치  김해시 구지로 180번길 25동상동\r\n 나 건물규모  23층108084 총 14개 점포2층 7개 3층 7개\r\n 다 입점현황\r\n   2층  201호도시락 202호오리탕 204호창고 205호전시공간 \r\n           206호국밥류 207호샐러드류 209호전시공간 210호분식 \r\n   3층  302호커피디저트류 304305호다문화카페 306호캔들방향제                307호네일아트 308호타로심리상담 309호그림공방\r\n\x0b\x0b 라 현황사진\r\n청년몰 외부 및 주변분성광장\r\n2 모집개요\r\n 가 \x0b\x0b모집점포  3층 2개소\r\n호수\r\n면 적\r\n연간사용료원\r\n계\r\n전용면적\r\n공유면적\r\n301호\r\n6467\r\n3240\r\n3227\r\n1422740원월118560\r\n303호\r\n7321\r\n4094\r\n3227\r\n1610620원월134210\r\n    \r\n     면적당 사용료 22000원 부가세10 미포함\r\n 나 모집분야 \r\n    식품위생법 제21조영업의종류에 의한 식품접객업 중 휴게음식점 또는 제과점 영업일반음식점 불가\r\n    신청자의 창업 아이템에 따라 점포 내 기존 시설물의 보존 및 활용   범위내에서 도소매업 가능부서와 사전 협의 \r\n 다 신청자격 \r\n   공고일 기준 관내 주소지를 둔 만19세 이상 만39세 이하 청년\r\n   공고일 기준 사업자등록을 하지 않은 자단 사업자등록 이력이 있어도       폐업신고 등으로 신청일 현재 사업자가 아니면 신청가능  \r\n\x0b\x0b\r\n  신청 제외 대상
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Github/code
# Out:
# /content/drive/MyDrive/Github/code

# %%
# !git config --global user.email 'qls5528@gmail.com'
# !git config --global user.name 'janghyebinee'

# %%
# !git add '텍스트 분석'.ipynb

# %%
# !git commit -m '텍스트 분석'
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes not staged for commit:
# 	modified:   test.ipynb
#
# Untracked files:
# 	"\341\204\200\341\205\265\341\206\267\341\204\222\341\205\242\341\204\211\341\205\241\341\204\205\341\205\241\341\206\274\341\204\211\341\205\241\341\206\274\341\204\221\341\205\256\341\206\267\341\204\200\341\205\257\341\206\253 \341\204\217\341\205\251\341\204\203\341\205\263\341\204\214\341\205\245\341\206\274\341\204\205\341\205\265_\341\204\200\341\205\256\341\204\206\341\205\242\341\204\202\341\205\242\341\204\213\341\205\247\341\206\250"
# 	"\341\204\220\341\205\246\341\206\250\341\204\211\341\205\263\341\204\220\341\205\263 \341\204\207\341\205\256\341\206\253\341\204\211\341\205\245\341\206\250.ipynb"
#
# no changes added to commit
# Everything up-to-date

# %%
pwd
# Out:
# '/content/drive/MyDrive/Github/code'
